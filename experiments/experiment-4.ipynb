# %% [markdown]
# # Experiment 4

# %% [markdown]
# Experiment 4 aims to explore the effect of swarm size on the performance of the swarm in exploring the pipe network. It does this by comparing the percentage of the pipe links explored in 100 turns for each swarm size. The swarm size is varied from 10 to 50 and for each swarm size and each swarm control method, the starting node is the same for each agent and 15 different starting nodes are examined to reduce the effect of the starting node on the results.

# %%
import random
random.seed(42)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import networkx as nx

# %%
import logging

from src.simulation import Simulation
from src.network import Network
from src.render import Render

logging.disable(logging.CRITICAL)

# %%
# Relative Path to Network INP File
network_file = "networks/Net3.inp"
# Create the environment
env = Network(network_file)
# Get all the nodes in the network with degree = 1 - these are the possible start nodes
g = env.water_network_model.to_graph().to_undirected()
deg = g.degree
start_pool = [node for node, degree in deg if degree == 1]
print(f"Start Pool: {start_pool}")
print(f"Number of Start Nodes: {len(start_pool)}")
print(f"Number of Nodes: {len(g.nodes)}")
print(f"Number of Links: {len(g.edges)}")
# Out:
# Start Pool: ['15', '35', '131', '166', '167', '203', '219', '225', '231', '243', '253', 'River', 'Lake', '1', '2', '3']
# Number of Start Nodes: 16
# Number of Nodes: 97
# Number of Links: 119

# %% [markdown]
# ## Create simulations
#
# ### Simulation parameters
#
# - env: the network environment
# - num_agents: the number of agents to create (this will vary)
# - swarm: whether to use swarm intelligence - all options will be tested
# - swarm_config: the configuration of the swarm - all options will be tested
# - start_node: the start node of the agents - a random node will be chosen from the start node pool
# - max_turns: the maximum number of turns to run the simulation for

# %%
start_nodes = start_pool[:15]
number_of_agents = [10, 20, 30, 40, 50]
max_turns = 20

print(f"Start Nodes: {start_nodes}")
# Out:
# Start Nodes: ['15', '35', '131', '166', '167', '203', '219', '225', '231', '243', '253', 'River', 'Lake', '1', '2']

# %% [markdown]
# ### Experiment 4.1
#
# - env: the network environment
# - num_agents: 10, 20, 30, 40, 50
# - swarm: False
# - swarm_config: None
# - start_node: a random node from the start node pool
# - max_turns: 100
# - run_until_complete: False
# - metric: 'pct_links_explored'
# - filepath: notable-results/Experiment4/NoSwarm

# %%
simulations_4_1 = []

for agent_num in number_of_agents:
    for start_node in start_nodes:
        print(f"Number of Agents: {agent_num} - Start Node: {start_node}")
        sim = Simulation(env, num_agents=agent_num, swarm=False, start_positions=[start_node], filepath="notable-results/Experiment-4/NoSwarm")
        sim.run(max_turns=max_turns)
        simulations_4_1.append((agent_num, start_node, sim.path_to_results_directory))
    
print(f"Done {len(simulations_4_1)} simulations: {simulations_4_1}")
# Out:
# Number of Agents: 10 - Start Node: 15
# Number of Agents: 10 - Start Node: 35
# Number of Agents: 10 - Start Node: 131
# Number of Agents: 10 - Start Node: 166
# Number of Agents: 10 - Start Node: 167
# Number of Agents: 10 - Start Node: 203
# Number of Agents: 10 - Start Node: 219
# Number of Agents: 10 - Start Node: 225
# Number of Agents: 10 - Start Node: 231
# Number of Agents: 10 - Start Node: 243
# Number of Agents: 10 - Start Node: 253
# Number of Agents: 10 - Start Node: River
# Number of Agents: 10 - Start Node: Lake
# Number of Agents: 10 - Start Node: 1
# Number of Agents: 10 - Start Node: 2
# Number of Agents: 20 - Start Node: 15
# Number of Agents: 20 - Start Node: 35
# Number of Agents: 20 - Start Node: 131
# Number of Agents: 20 - Start Node: 166
# Number of Agents: 20 - Start Node: 167
# Number of Agents: 20 - Start Node: 203
# Number of Agents: 20 - Start Node: 219
# Number of Agents: 20 - Start Node: 225
# Number of Agents: 20 - Start Node: 231
# Number of Agents: 20 - Start Node: 243
# Number of Agents: 20 - Start Node: 253
# Number of Agents: 20 - Start Node: River
# Number of Agents: 20 - Start Node: Lake
# Number of Agents: 20 - Start Node: 1
# Number of Agents: 20 - Start Node: 2
# Number of Agents: 30 - Start Node: 15
# Number of Agents: 30 - Start Node: 35
# Number of Agents: 30 - Start Node: 131
# Number of Agents: 30 - Start Node: 166
# Number of Agents: 30 - Start Node: 167
# Number of Agents: 30 - Start Node: 203
# Number of Agents: 30 - Start Node: 219
# Number of Agents: 30 - Start Node: 225
# Number of Agents: 30 - Start Node: 231
# Number of Agents: 30 - Start Node: 243
# Number of Agents: 30 - Start Node: 253
# Number of Agents: 30 - Start Node: River
# Number of Agents: 30 - Start Node: Lake
# Number of Agents: 30 - Start Node: 1
# Number of Agents: 30 - Start Node: 2
# Number of Agents: 40 - Start Node: 15
# Number of Agents: 40 - Start Node: 35
# Number of Agents: 40 - Start Node: 131
# Number of Agents: 40 - Start Node: 166
# Number of Agents: 40 - Start Node: 167
# Number of Agents: 40 - Start Node: 203
# Number of Agents: 40 - Start Node: 219
# Number of Agents: 40 - Start Node: 225
# Number of Agents: 40 - Start Node: 231
# Number of Agents: 40 - Start Node: 243
# Number of Agents: 40 - Start Node: 253
# Number of Agents: 40 - Start Node: River
# Number of Agents: 40 - Start Node: Lake
# Number of Agents: 40 - Start Node: 1
# Number of Agents: 40 - Start Node: 2
# Number of Agents: 50 - Start Node: 15
# Number of Agents: 50 - Start Node: 35
# Number of Agents: 50 - Start Node: 131
# Number of Agents: 50 - Start Node: 166
# Number of Agents: 50 - Start Node: 167
# Number of Agents: 50 - Start Node: 203
# Number of Agents: 50 - Start Node: 219
# Number of Agents: 50 - Start Node: 225
# Number of Agents: 50 - Start Node: 231
# Number of Agents: 50 - Start Node: 243
# Number of Agents: 50 - Start Node: 253
# Number of Agents: 50 - Start Node: River
# Number of Agents: 50 - Start Node: Lake
# Number of Agents: 50 - Start Node: 1
# Number of Agents: 50 - Start Node: 2
# Done 75 simulations: [(10, '15', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135419'), (10, '35', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135420'), (10, '131', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135421'), (10, '166', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135422'), (10, '167', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135423'), (10, '203', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135423'), (10, '219', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135425'), (10, '225', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135425'), (10, '231', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135426'), (10, '243', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135427'), (10, '253', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135427'), (10, 'River', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135428'), (10, 'Lake', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135429'), (10, '1', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135430'), (10, '2', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135430'), (20, '15', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135431'), (20, '35', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135432'), (20, '131', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135433'), (20, '166', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135434'), (20, '167', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135434'), (20, '203', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135435'), (20, '219', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135436'), (20, '225', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135436'), (20, '231', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135437'), (20, '243', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135438'), (20, '253', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135438'), (20, 'River', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135439'), (20, 'Lake', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135440'), (20, '1', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135440'), (20, '2', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135441'), (30, '15', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135442'), (30, '35', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135443'), (30, '131', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135443'), (30, '166', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135444'), (30, '167', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135445'), (30, '203', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135446'), (30, '219', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135446'), (30, '225', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135447'), (30, '231', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135448'), (30, '243', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135448'), (30, '253', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135449'), (30, 'River', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135450'), (30, 'Lake', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135451'), (30, '1', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135452'), (30, '2', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135452'), (40, '15', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135453'), (40, '35', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135455'), (40, '131', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135456'), (40, '166', 'notable-results/Experiment-4/NoSwarm/simulation_20230329_135456'), (40, '167', 'notable-results/Experiment-4/NoSwarm/simulation_20230329 ...

# %% [markdown]
# ### Experiment 4.2
#
# - env: the network environment
# - num_agents: 10, 20, 30, 40, 50
# - swarm: True
# - swarm_config: naive
# - start_node: a random node from the start node pool
# - max_turns: 100
# - run_until_complete: False
# - metric: 'pct_links_explored'
# - filepath: notable-results/Experiment4/NaiveSwarm

# %%
swarm_config = {'swarm': True, 'swarm_type': 'naive'}

simulations_4_2 = []

for agent_num in number_of_agents:
    for start_node in start_nodes:
        print(f"Number of Agents: {agent_num} - Start Node: {start_node}")
        sim = Simulation(env, num_agents=agent_num, swarm=True, swarm_config=swarm_config, start_positions=[start_node], filepath="notable-results/Experiment-4/NaiveSwarm")
        sim.run(max_turns=max_turns)
        simulations_4_2.append((agent_num, start_node, sim.path_to_results_directory))
    
print(f"Done {len(simulations_4_2)} simulations: {simulations_4_2}")
# Out:
# Number of Agents: 10 - Start Node: 15
# Number of Agents: 10 - Start Node: 35
# Number of Agents: 10 - Start Node: 131
# Number of Agents: 10 - Start Node: 166
# Number of Agents: 10 - Start Node: 167
# Number of Agents: 10 - Start Node: 203
# Number of Agents: 10 - Start Node: 219
# Number of Agents: 10 - Start Node: 225
# Number of Agents: 10 - Start Node: 231
# Number of Agents: 10 - Start Node: 243
# Number of Agents: 10 - Start Node: 253
# Number of Agents: 10 - Start Node: River
# Number of Agents: 10 - Start Node: Lake
# Number of Agents: 10 - Start Node: 1
# Number of Agents: 10 - Start Node: 2
# Number of Agents: 20 - Start Node: 15
# Number of Agents: 20 - Start Node: 35
# Number of Agents: 20 - Start Node: 131
# Number of Agents: 20 - Start Node: 166
# Number of Agents: 20 - Start Node: 167
# Number of Agents: 20 - Start Node: 203
# Number of Agents: 20 - Start Node: 219
# Number of Agents: 20 - Start Node: 225
# Number of Agents: 20 - Start Node: 231
# Number of Agents: 20 - Start Node: 243
# Number of Agents: 20 - Start Node: 253
# Number of Agents: 20 - Start Node: River
# Number of Agents: 20 - Start Node: Lake
# Number of Agents: 20 - Start Node: 1
# Number of Agents: 20 - Start Node: 2
# Number of Agents: 30 - Start Node: 15
# Number of Agents: 30 - Start Node: 35
# Number of Agents: 30 - Start Node: 131
# Number of Agents: 30 - Start Node: 166
# Number of Agents: 30 - Start Node: 167
# Number of Agents: 30 - Start Node: 203
# Number of Agents: 30 - Start Node: 219
# Number of Agents: 30 - Start Node: 225
# Number of Agents: 30 - Start Node: 231
# Number of Agents: 30 - Start Node: 243
# Number of Agents: 30 - Start Node: 253
# Number of Agents: 30 - Start Node: River
# Number of Agents: 30 - Start Node: Lake
# Number of Agents: 30 - Start Node: 1
# Number of Agents: 30 - Start Node: 2
# Number of Agents: 40 - Start Node: 15
# Number of Agents: 40 - Start Node: 35
# Number of Agents: 40 - Start Node: 131
# Number of Agents: 40 - Start Node: 166
# Number of Agents: 40 - Start Node: 167
# Number of Agents: 40 - Start Node: 203
# Number of Agents: 40 - Start Node: 219
# Number of Agents: 40 - Start Node: 225
# Number of Agents: 40 - Start Node: 231
# Number of Agents: 40 - Start Node: 243
# Number of Agents: 40 - Start Node: 253
# Number of Agents: 40 - Start Node: River
# Number of Agents: 40 - Start Node: Lake
# Number of Agents: 40 - Start Node: 1
# Number of Agents: 40 - Start Node: 2
# Number of Agents: 50 - Start Node: 15
# Number of Agents: 50 - Start Node: 35
# Number of Agents: 50 - Start Node: 131
# Number of Agents: 50 - Start Node: 166
# Number of Agents: 50 - Start Node: 167
# Number of Agents: 50 - Start Node: 203
# Number of Agents: 50 - Start Node: 219
# Number of Agents: 50 - Start Node: 225
# Number of Agents: 50 - Start Node: 231
# Number of Agents: 50 - Start Node: 243
# Number of Agents: 50 - Start Node: 253
# Number of Agents: 50 - Start Node: River
# Number of Agents: 50 - Start Node: Lake
# Number of Agents: 50 - Start Node: 1
# Number of Agents: 50 - Start Node: 2
# Done 75 simulations: [(10, '15', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135522'), (10, '35', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135523'), (10, '131', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135524'), (10, '166', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135525'), (10, '167', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135525'), (10, '203', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135526'), (10, '219', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135527'), (10, '225', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135527'), (10, '231', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135528'), (10, '243', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135529'), (10, '253', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135529'), (10, 'River', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135530'), (10, 'Lake', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135531'), (10, '1', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135531'), (10, '2', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135532'), (20, '15', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135533'), (20, '35', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135533'), (20, '131', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135534'), (20, '166', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135535'), (20, '167', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135535'), (20, '203', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135536'), (20, '219', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135537'), (20, '225', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135537'), (20, '231', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135538'), (20, '243', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135539'), (20, '253', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135539'), (20, 'River', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135540'), (20, 'Lake', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135541'), (20, '1', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135542'), (20, '2', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135543'), (30, '15', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135543'), (30, '35', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135544'), (30, '131', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135545'), (30, '166', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135546'), (30, '167', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135546'), (30, '203', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135547'), (30, '219', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135548'), (30, '225', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135548'), (30, '231', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135549'), (30, '243', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135550'), (30, '253', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135550'), (30, 'River', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135551'), (30, 'Lake', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135552'), (30, '1', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135552'), (30, '2', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135553'), (40, '15', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135554'), (40, '35', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135555'), (40, '131', 'notable-results/Experiment-4/NaiveSwarm/simulation_20230329_135555'), (40,  ...

# %% [markdown]
# ### Experiment 4.3
#
# - env: the network environment
# - num_agents: 10, 20, 30, 40, 50
# - swarm: True
# - swarm_config: informed, mean
# - start_node: a random node from the start node pool
# - max_turns: 100
# - run_until_complete: False
# - metric: 'pct_links_explored'
# - filepath: notable-results/Experiment4/InformedMeanSwarm

# %%
swarm_config = {'swarm': True, 'swarm_type': 'informed', 'allocation_threshold': 'mean'}

simulations_4_3 = []

for agent_num in number_of_agents:
    for start_node in start_nodes:
        print(f"Number of Agents: {agent_num} - Start Node: {start_node}")
        sim = Simulation(env, num_agents=agent_num, swarm=True, swarm_config=swarm_config, start_positions=[start_node], filepath="notable-results/Experiment-4/InformedMeanSwarm")
        sim.run(max_turns=max_turns)
        simulations_4_3.append((agent_num, start_node, sim.path_to_results_directory))
    
print(f"Done {len(simulations_4_3)} simulations: {simulations_4_3}")
# Out:
# Number of Agents: 10 - Start Node: 15
# Number of Agents: 10 - Start Node: 35
# Number of Agents: 10 - Start Node: 131
# Number of Agents: 10 - Start Node: 166
# Number of Agents: 10 - Start Node: 167
# Number of Agents: 10 - Start Node: 203
# Number of Agents: 10 - Start Node: 219
# Number of Agents: 10 - Start Node: 225
# Number of Agents: 10 - Start Node: 231
# Number of Agents: 10 - Start Node: 243
# Number of Agents: 10 - Start Node: 253
# Number of Agents: 10 - Start Node: River
# Number of Agents: 10 - Start Node: Lake
# Number of Agents: 10 - Start Node: 1
# Number of Agents: 10 - Start Node: 2
# Number of Agents: 20 - Start Node: 15
# Number of Agents: 20 - Start Node: 35
# Number of Agents: 20 - Start Node: 131
# Number of Agents: 20 - Start Node: 166
# Number of Agents: 20 - Start Node: 167
# Number of Agents: 20 - Start Node: 203
# Number of Agents: 20 - Start Node: 219
# Number of Agents: 20 - Start Node: 225
# Number of Agents: 20 - Start Node: 231
# Number of Agents: 20 - Start Node: 243
# Number of Agents: 20 - Start Node: 253
# Number of Agents: 20 - Start Node: River
# Number of Agents: 20 - Start Node: Lake
# Number of Agents: 20 - Start Node: 1
# Number of Agents: 20 - Start Node: 2
# Number of Agents: 30 - Start Node: 15
# Number of Agents: 30 - Start Node: 35
# Number of Agents: 30 - Start Node: 131
# Number of Agents: 30 - Start Node: 166
# Number of Agents: 30 - Start Node: 167
# Number of Agents: 30 - Start Node: 203
# Number of Agents: 30 - Start Node: 219
# Number of Agents: 30 - Start Node: 225
# Number of Agents: 30 - Start Node: 231
# Number of Agents: 30 - Start Node: 243
# Number of Agents: 30 - Start Node: 253
# Number of Agents: 30 - Start Node: River
# Number of Agents: 30 - Start Node: Lake
# Number of Agents: 30 - Start Node: 1
# Number of Agents: 30 - Start Node: 2
# Number of Agents: 40 - Start Node: 15
# Number of Agents: 40 - Start Node: 35
# Number of Agents: 40 - Start Node: 131
# Number of Agents: 40 - Start Node: 166
# Number of Agents: 40 - Start Node: 167
# Number of Agents: 40 - Start Node: 203
# Number of Agents: 40 - Start Node: 219
# Number of Agents: 40 - Start Node: 225
# Number of Agents: 40 - Start Node: 231
# Number of Agents: 40 - Start Node: 243
# Number of Agents: 40 - Start Node: 253
# Number of Agents: 40 - Start Node: River
# Number of Agents: 40 - Start Node: Lake
# Number of Agents: 40 - Start Node: 1
# Number of Agents: 40 - Start Node: 2
# Number of Agents: 50 - Start Node: 15
# Number of Agents: 50 - Start Node: 35
# Number of Agents: 50 - Start Node: 131
# Number of Agents: 50 - Start Node: 166
# Number of Agents: 50 - Start Node: 167
# Number of Agents: 50 - Start Node: 203
# Number of Agents: 50 - Start Node: 219
# Number of Agents: 50 - Start Node: 225
# Number of Agents: 50 - Start Node: 231
# Number of Agents: 50 - Start Node: 243
# Number of Agents: 50 - Start Node: 253
# Number of Agents: 50 - Start Node: River
# Number of Agents: 50 - Start Node: Lake
# Number of Agents: 50 - Start Node: 1
# Number of Agents: 50 - Start Node: 2
# Done 75 simulations: [(10, '15', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135621'), (10, '35', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135622'), (10, '131', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135623'), (10, '166', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135624'), (10, '167', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135624'), (10, '203', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135625'), (10, '219', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135626'), (10, '225', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135627'), (10, '231', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135627'), (10, '243', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135628'), (10, '253', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135628'), (10, 'River', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135629'), (10, 'Lake', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135630'), (10, '1', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135630'), (10, '2', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135631'), (20, '15', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135631'), (20, '35', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135632'), (20, '131', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135633'), (20, '166', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135634'), (20, '167', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135634'), (20, '203', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135635'), (20, '219', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135636'), (20, '225', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135636'), (20, '231', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135637'), (20, '243', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135637'), (20, '253', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135638'), (20, 'River', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135638'), (20, 'Lake', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135639'), (20, '1', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135640'), (20, '2', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135640'), (30, '15', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135641'), (30, '35', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135642'), (30, '131', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135642'), (30, '166', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135643'), (30, '167', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135644'), (30, '203', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135644'), (30, '219', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135645'), (30, '225', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135646'), (30, '231', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135647'), (30, '243', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135648'), (30, '253', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135648'), (30, 'River', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135649'), (30, 'Lake', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135650'), (30, '1', 'notable-results/Experiment-4/InformedMeanSwarm/simulation_20230329_135650'), (30, '2', 'notable-result ...

# %% [markdown]
# ### Experiment 4.4
#
# - env: the network environment
# - num_agents: 10, 20, 30, 40, 50
# - swarm: True
# - swarm_config: informed, median
# - start_node: a random node from the start node pool
# - max_turns: 100
# - run_until_complete: False
# - metric: 'pct_links_explored'
# - filepath: notable-results/Experiment4/InformedMedianSwarm

# %%
swarm_config = {'swarm': True, 'swarm_type': 'informed', 'allocation_threshold': 'median'}

simulations_4_4 = []

for agent_num in number_of_agents:
    for start_node in start_nodes:
        print(f"Number of Agents: {agent_num} - Start Node: {start_node}")
        sim = Simulation(env, num_agents=agent_num, swarm=True, swarm_config=swarm_config, start_positions=[start_node], filepath="notable-results/Experiment-4/InformedMedianSwarm")
        sim.run(max_turns=max_turns)
        simulations_4_4.append((agent_num, start_node, sim.path_to_results_directory))
    
print(f"Done {len(simulations_4_4)} simulations: {simulations_4_4}")
# Out:
# Number of Agents: 10 - Start Node: 15
# Number of Agents: 10 - Start Node: 35
# Number of Agents: 10 - Start Node: 131
# Number of Agents: 10 - Start Node: 166
# Number of Agents: 10 - Start Node: 167
# Number of Agents: 10 - Start Node: 203
# Number of Agents: 10 - Start Node: 219
# Number of Agents: 10 - Start Node: 225
# Number of Agents: 10 - Start Node: 231
# Number of Agents: 10 - Start Node: 243
# Number of Agents: 10 - Start Node: 253
# Number of Agents: 10 - Start Node: River
# Number of Agents: 10 - Start Node: Lake
# Number of Agents: 10 - Start Node: 1
# Number of Agents: 10 - Start Node: 2
# Number of Agents: 20 - Start Node: 15
# Number of Agents: 20 - Start Node: 35
# Number of Agents: 20 - Start Node: 131
# Number of Agents: 20 - Start Node: 166
# Number of Agents: 20 - Start Node: 167
# Number of Agents: 20 - Start Node: 203
# Number of Agents: 20 - Start Node: 219
# Number of Agents: 20 - Start Node: 225
# Number of Agents: 20 - Start Node: 231
# Number of Agents: 20 - Start Node: 243
# Number of Agents: 20 - Start Node: 253
# Number of Agents: 20 - Start Node: River
# Number of Agents: 20 - Start Node: Lake
# Number of Agents: 20 - Start Node: 1
# Number of Agents: 20 - Start Node: 2
# Number of Agents: 30 - Start Node: 15
# Number of Agents: 30 - Start Node: 35
# Number of Agents: 30 - Start Node: 131
# Number of Agents: 30 - Start Node: 166
# Number of Agents: 30 - Start Node: 167
# Number of Agents: 30 - Start Node: 203
# Number of Agents: 30 - Start Node: 219
# Number of Agents: 30 - Start Node: 225
# Number of Agents: 30 - Start Node: 231
# Number of Agents: 30 - Start Node: 243
# Number of Agents: 30 - Start Node: 253
# Number of Agents: 30 - Start Node: River
# Number of Agents: 30 - Start Node: Lake
# Number of Agents: 30 - Start Node: 1
# Number of Agents: 30 - Start Node: 2
# Number of Agents: 40 - Start Node: 15
# Number of Agents: 40 - Start Node: 35
# Number of Agents: 40 - Start Node: 131
# Number of Agents: 40 - Start Node: 166
# Number of Agents: 40 - Start Node: 167
# Number of Agents: 40 - Start Node: 203
# Number of Agents: 40 - Start Node: 219
# Number of Agents: 40 - Start Node: 225
# Number of Agents: 40 - Start Node: 231
# Number of Agents: 40 - Start Node: 243
# Number of Agents: 40 - Start Node: 253
# Number of Agents: 40 - Start Node: River
# Number of Agents: 40 - Start Node: Lake
# Number of Agents: 40 - Start Node: 1
# Number of Agents: 40 - Start Node: 2
# Number of Agents: 50 - Start Node: 15
# Number of Agents: 50 - Start Node: 35
# Number of Agents: 50 - Start Node: 131
# Number of Agents: 50 - Start Node: 166
# Number of Agents: 50 - Start Node: 167
# Number of Agents: 50 - Start Node: 203
# Number of Agents: 50 - Start Node: 219
# Number of Agents: 50 - Start Node: 225
# Number of Agents: 50 - Start Node: 231
# Number of Agents: 50 - Start Node: 243
# Number of Agents: 50 - Start Node: 253
# Number of Agents: 50 - Start Node: River
# Number of Agents: 50 - Start Node: Lake
# Number of Agents: 50 - Start Node: 1
# Number of Agents: 50 - Start Node: 2
# Done 75 simulations: [(10, '15', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135717'), (10, '35', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135718'), (10, '131', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135719'), (10, '166', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135719'), (10, '167', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135720'), (10, '203', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135720'), (10, '219', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135721'), (10, '225', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135722'), (10, '231', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135722'), (10, '243', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135723'), (10, '253', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135723'), (10, 'River', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135724'), (10, 'Lake', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135724'), (10, '1', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135725'), (10, '2', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135725'), (20, '15', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135726'), (20, '35', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135727'), (20, '131', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135728'), (20, '166', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135728'), (20, '167', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135729'), (20, '203', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135729'), (20, '219', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135730'), (20, '225', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135731'), (20, '231', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135731'), (20, '243', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135732'), (20, '253', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135732'), (20, 'River', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135733'), (20, 'Lake', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135734'), (20, '1', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135734'), (20, '2', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135735'), (30, '15', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135735'), (30, '35', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135736'), (30, '131', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135737'), (30, '166', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135737'), (30, '167', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135738'), (30, '203', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135739'), (30, '219', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135740'), (30, '225', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135741'), (30, '231', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135741'), (30, '243', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135742'), (30, '253', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135743'), (30, 'River', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135743'), (30, 'Lake', 'notable-results/Experiment-4/InformedMedianSwarm/simulation_20230329_135744'), (30, '1', 'notable-results/ ...

# %% [markdown]
# ## Results

# %% [markdown]
# **What do I have?**
#
# csv files with the following columns:
# - turn number
# - the percentage of nodes explored at that turn
# - the percentage of links explored at that turn
# - the node novelty at that turn
# - the link novelty at that turn
#
# **What do I want?**
#
# Number of agents on the x-axis and the percentage of links explored on the y-axis?
#
# Number of agents on the x-axis and the percentage of nodes explored on the y-axis?
#
# Number of agents on the x-axis and the number of turns to explore 100% of the links on the y-axis?

# %%
def read_results(simulations):
    results = []
    for sim in simulations:
        num_agents, start_node, path = sim
        df = pd.read_csv(f"{path}/results.csv")
        df['num_agents'] = num_agents
        df['start_node'] = start_node
        df.num_agents = num_agents
        df.start_node = start_node
        
        results.append(df)
    return results

def sanitise_results(results):
    # Group the results into groups with the same number of agents
    results = pd.concat(results)
    results = results.groupby(['num_agents', 'start_node']).agg({'pct_links_explored': 'max'})
    results = results.reset_index()
    
    # Get the mean and standard deviation for each number of agents
    results = results.groupby('num_agents').agg({'pct_links_explored': ['mean', 'std', 'min', 'max']})
    results = results.reset_index()
    results.columns = ['num_agents', 'mean_pct_links_explored', 'std', 'min', 'max']
    
    return results

def get_results(simulations):
    results = read_results(simulations)
    results = sanitise_results(results)
    return results

# %%
results_3_1 = get_results(simulations_4_1)
results_3_2 = get_results(simulations_4_2)
results_3_3 = get_results(simulations_4_3)
results_3_4 = get_results(simulations_4_4)

# %%
# Plot the results
fig, ax = plt.subplots(figsize=(10, 6))

ax.errorbar(results_3_1['num_agents'], results_3_1['mean_pct_links_explored'], yerr=results_3_1['std'], label="No Swarm", capsize=5)
ax.errorbar(results_3_2['num_agents'], results_3_2['mean_pct_links_explored'], yerr=results_3_2['std'], label="Naive Swarm", capsize=5)
ax.errorbar(results_3_3['num_agents'], results_3_3['mean_pct_links_explored'], yerr=results_3_3['std'], label="Informed Swarm (Mean)", capsize=5)
ax.errorbar(results_3_4['num_agents'], results_3_4['mean_pct_links_explored'], yerr=results_3_4['std'], label="Informed Swarm (Median)", capsize=5)

ax.set_xticks(number_of_agents)

ax.set_xlabel("Number of Agents")
ax.set_ylabel("Percentage of Links Explored")
ax.set_title(f"Percentage of Links Explored in {max_turns} turns vs Number of Agents")
ax.legend()

plt.show()

# %%
# Replot the above graph but as a bar chart
fig, ax = plt.subplots(figsize=(10, 6))

OFFSET = 0.6

ax.bar(results_3_1['num_agents'], results_3_1['mean_pct_links_explored'], width=OFFSET, label="No Swarm", align='edge')
ax.bar(results_3_2['num_agents'] + 1, results_3_2['mean_pct_links_explored'], width=OFFSET, label="Naive Swarm", align='edge')
ax.bar(results_3_3['num_agents'] + 2, results_3_3['mean_pct_links_explored'], width=OFFSET, label="Informed Swarm (Mean)", align='edge')
ax.bar(results_3_4['num_agents'] + 3, results_3_4['mean_pct_links_explored'], width=OFFSET, label="Informed Swarm (Median)", align='edge')

ax.set_xticks(number_of_agents)
ax.set_ylim(0, 75)

ax.set_xlabel("Number of Agents")
ax.set_ylabel(f"Mean Percentage of Links Explored in {max_turns} turns")
ax.set_title(f"Mean Percentage of Links Explored in {max_turns} turns vs Number of Agents")
ax.legend()

plt.show()

# %%
# Normalise the results according to the number of agents
results_3_1['mean_pct_links_explored'] = results_3_1['mean_pct_links_explored'] / results_3_1['num_agents']
results_3_2['mean_pct_links_explored'] = results_3_2['mean_pct_links_explored'] / results_3_2['num_agents']
results_3_3['mean_pct_links_explored'] = results_3_3['mean_pct_links_explored'] / results_3_3['num_agents']
results_3_4['mean_pct_links_explored'] = results_3_4['mean_pct_links_explored'] / results_3_4['num_agents']

# %%
# Plot the normalised results as a bar chart
fig, ax = plt.subplots(figsize=(10, 6))

OFFSET = 0.6

ax.bar(results_3_1['num_agents'], results_3_1['mean_pct_links_explored'], width=OFFSET, label="No Swarm", align='edge')
ax.bar(results_3_2['num_agents'] + 1, results_3_2['mean_pct_links_explored'], width=OFFSET, label="Naive Swarm", align='edge')
ax.bar(results_3_3['num_agents'] + 2, results_3_3['mean_pct_links_explored'], width=OFFSET, label="Informed Swarm (Mean)", align='edge')
ax.bar(results_3_4['num_agents'] + 3, results_3_4['mean_pct_links_explored'], width=OFFSET, label="Informed Swarm (Median)", align='edge')

ax.set_xticks(number_of_agents)
ax.set_ylim(0, 5)

ax.set_xlabel("Number of Agents")
ax.set_ylabel(f"Mean Percentage of Links Explored by a single agent in the swarm in {max_turns} turns")
ax.set_title(f"Mean Percentage of Links Explored by a single agent in the swarm in {max_turns} turns vs Number of Agents")
ax.legend()

plt.show()

# %%
# Plot the normalised results as a bar chart
fig, ax = plt.subplots(figsize=(10, 6))

OFFSET = 0.6

ax.bar(results_3_1['num_agents'], results_3_1['mean_pct_links_explored'], width=OFFSET, label="No Swarm", align='edge')
ax.bar(results_3_2['num_agents'] + 1, results_3_2['mean_pct_links_explored'], width=OFFSET, label="Naive Swarm", align='edge')
ax.bar(results_3_3['num_agents'] + 2, results_3_3['mean_pct_links_explored'], width=OFFSET, label="Informed Swarm (Mean)", align='edge')
ax.bar(results_3_4['num_agents'] + 3, results_3_4['mean_pct_links_explored'], width=OFFSET, label="Informed Swarm (Median)", align='edge')

ax.set_xticks(number_of_agents)
ax.set_ylim(0, 5)

ax.set_xlabel("Number of Agents")
ax.set_ylabel(f"Mean Percentage of Links Explored")
ax.set_title(f"Mean Percentage of Links Explored by a single agent in the swarm in {max_turns} turns vs Number of Agents")
ax.legend()

plt.show()
